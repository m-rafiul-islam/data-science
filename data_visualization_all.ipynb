# %% [markdown]
# <a href="https://colab.research.google.com/github/m-rafiul-islam/data-science/blob/main/data_visualization_all.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div style="text-align:center">
#     <h1>Data visualization in Python <br>with Matplotlib, Seaborn, Plotly and Dash</h1>
#     <br>
# </div>

# %% [markdown]
# <img src="data:image/png;base64,..." />

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br>
#
# <div style="text-align:center">
#     <h1>Matplotlib basics</h1>
#     <br>
# </div>

# %% [markdown]
# <img src="data:image/png;base64,..." />

# %% [markdown]
# ## Our first plot

# %% [markdown]
# ## Anatomy of a plot
#
# <img src="data:image/webp;base64,..."  width="70%"/>

# %% [markdown]
# ## Figure and axis

# %% [markdown]
# ## Matplotlib's two interfaces

# %% [markdown]
# ### Imperative interface

# %% [markdown]
# ### Object oriented interface

# %% [markdown]
# ## Marking points in the graph

# %% [markdown]
# ## Format axes properties

# %% [markdown]
# ## Data visualization with Matplotlib

# %% [markdown]
# ### The Iris dataset

# %% [markdown]
# ### How many records do we have of each class?

# %% [markdown]
# #### Styling our pie chart

# %% [markdown]
# ### Can we tell apart iris flowers by their petals?

# %% [markdown]
# ### Does sepal length help?

# %% [markdown]
# ### What is the range of values for sepal/petal width/length?

# %% [markdown]
# <br><br><br>
# <img src="data:image/webp;base64,..." width="60%"/>
# <br><br><br>

# %% [markdown]
# ### How are feature values distributed?

# %% [markdown]
# ### What is the average feature value per species?

# %% [markdown]
# ### Setting global styles

# %% [markdown]
# ## Image plot

# %% [markdown]
# ### Grayscale

# %% [markdown]
# ### Colormaps

# %% [markdown]
# ### Creating complex layouts using Gridspec

# %% [markdown]
# ### Channel histogram

# %% [markdown]
# ### Low-res

# %% [markdown]
# #### Nearest interpolation

# %% [markdown]
# #### Bicubic interpolation

# %% [markdown]
# ### Saving figures as image files

# %% [markdown]
# <br><br><br><br><br><br><br><br><br><br><br><br>
#
# <div style="text-align:center">
#     <h1>Seaborn</h1>
# <img src="data:image/jpeg;base64,..." width="35%"/>
# </div>

# %% [markdown]
# <img src="data:image/png;base64,..." />

# %% [markdown]
# ## Figure level vs Axes level plots
# <br>

# %% [markdown]
# ### Figure level plots (relplot)

# %% [markdown]
# ### Axes level plot

# %% [markdown]
# ### Plot styles

# %% [markdown]
# ## Seaborn built-in datasets

# %% [markdown]
# ## The titanic dataset

# %% [markdown]
# ### Who was on the titanic?

# %% [markdown]
# ### How much did travelers pay?

# %% [markdown]
# ### Does paying more help your chances to survive

# %% [markdown]
# ### Where did they stay?

# %% [markdown]
# ### What are your odds of surviving?

# %% [markdown]
# #### Decompose the previous graph by sex

# %% [markdown]
# <br><br>
# ## Penguin species analysis

# %% [markdown]
# ### How can we tell penguin species apart?

# %% [markdown]
# <br><br>
# ## Flights dataset

# %% [markdown]
# <br><br><br><br><br><br><br>
#
# <div style="text-align:center">
#     <h1>Plotly and Dash</h1>
#     <br>
# <img src="data:image/jpeg;base64,..." width="25%"/></div>

# %% [markdown]
# ## Plotly express basics

# %% [markdown]
# ### Wind dataset

# %% [markdown]
# ### FMRI dataset

# %% [markdown]
# ### Stock Evolution

# %% [markdown]
# ### Diamonds dataset

# %% [markdown]
# #### How many diamonds do we have by cut/clarity/color

# %% [markdown]
# #### Does the cut affect the price?

# %% [markdown]
# #### Does the color affect the price?

# %% [markdown]
# #### Does the clarity affect the price?

# %% [markdown]
# #### What variables affect the price?

# %% [markdown]
# #### Explore the relationship between carat, clarity, cut and price

# %% [markdown]
# #### Does color matter?

# %% [markdown]
# ### Carshare activity in the city of Montreal

# %% [markdown]
# ### Car crashes per state in the US

# %% [markdown]
# ## Introduction to Dash

# %% [markdown]
# ### Worldbank data

# %% [markdown]
# #### Evolution of GDP and Life expectancy by region

# %% [markdown]
# #### Evolution by country

# %% [markdown]
# #### Evolution trends by country

# %% [markdown]
# #### Population by country

# %% [markdown]
# #### Create the dashboard

# %% [markdown]
# ### Website traffic analysis

# %%
# %%bash
#
# pip install plotly==5.4 dash jupyter-dash
#
# mkdir assets/
# wget https://gist.githubusercontent.com/escape-velocity-labs/17c3ba12aef542afe5055a859e0fbd98/raw/af9e2431fb69c76618aeec9940cd5fd6deab8b1f/style.css -O assets/style.css
# wget https://gist.githubusercontent.com/escape-velocity-labs/81b8225d72306541018bf868f3a23436/raw/c14fdac538abc45f8e19c4828bb015aa931c41c5/web_data.csv -O web_data.csv

# %%
import pandas as pd
import dash
from dash import dcc
from dash import html
from dash.dependencies import Input, Output
from jupyter_dash import JupyterDash
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio

# %% [markdown]
# #### Dashboard structure

# %% [markdown]
# #### Dashboard header

# %% [markdown]
# #### Evolution of website visits

# %% [markdown]
# #### First row

# %% [markdown]
# #### Sales funnel

# %% [markdown]
# #### Distribution of visits by attribute

# %% [markdown]
# #### Second row

# %% [markdown]
# #### Visits by date and time

# %% [markdown]
# #### Distribution by country

# %% [markdown]
# #### Third row

# %% [markdown]
# #### Create the dashboard

# %% [markdown]
# <a href="https://colab.research.google.com/github/m-rafiul-islam/data-science/blob/main/april25_waffle_word_sea_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#                                                DATA 2365- INTRODUCTION TO DATA SCIENCE

# %% [markdown]
# **Topic: Visualization Tools**
#
# Learning Objectives:
# - Apply advanced visualization tools to create waffle charts and word clouds.
# - Use Seaborn with Matplotlib to generate attractive regression plots.

# %% [markdown]
# # Waffle Chart

# %% [markdown]
# Waffle Charts:
# What is a waffle charts?
#
# - A waffle chart is a great way to visualize data in relation to a whole or to highlight progress against a given threshold.
# For example, say immigration from Scandinavia to Canada
# is comprised only of immigration from Denmark, Norway, and Sweden, and we're
# interested in visualizing the contribution of each of these countries
# to the Scandinavian immigration to Canada. The main idea here is for a given
# waffle chart whose desired height and width are defined, the contribution of
# each country is transformed into a number of tiles that is proportional to
# the country's contribution to the total, so that more the contribution the more
# the tiles, resulting in what resembles a waffle when combined. Hence the name
# waffle chart.
# Unfortunately Matplotlib does not have a built-in function to
# create waffle charts.
# Therefore, in the lab session, I'll walk you through the
# process of creating your own Python function to create a waffle chart, so
# it's really important that you complete this module's lab session. And with this,
# we conclude our video on waffle charts. I'll see you in the next video.

# %% [markdown]
# https://github.com/JaziDesigns/IBM-Data-Science/blob/main/Waffle%20Charts%2C%20Regression%20Plots%20and%20Word%20Clouds%20using%20Python.ipynb

# %% [markdown]
# https://github.com/anandprabhakar0507/Python-Advanced-visualisation-tools-2/blob/master/DV0101EN-3-4-1-Waffle-Charts-Word-Clouds-and-Regression-Plots-py-v2.0.md
# https://www.youtube.com/watch?v=5DDj8uFWMGo

# %%
# pip install pywaffle 
import matplotlib.pyplot as plt
from pywaffle import Waffle

# %%
# Vote Percentage in 2016 US Presidential Election
data = {'Democratic': 48, 'Republican': 46, 'Libertarian': 3} 
fig = plt.figure(
    FigureClass=Waffle, 
    rows=5, 
    values=data
)
# Out:
# <Waffle size 432x288 with 1 Axes>

# %%
# Vote Percentage in 2016 US Presidential Election
data = {'Democratic': 48, 'Republican': 46, 'Libertarian': 3} 
fig = plt.figure(
    FigureClass=Waffle, 
    rows=5, 
    values=data,
    # legend= {'loc': 'upper right'}
    # legend= {'loc': 'upper left', 'bbox_to_anchor': (1.05, 1), 'fontsize': 8}
    legend= {'bbox_to_anchor': (1.05, 1)}
)
# Out:
# <Waffle size 432x288 with 1 Axes>

# %%
data.items()
# Out:
# dict_items([('Democratic', 48), ('Republican', 46), ('Libertarian', 3)])

# %%
# colors = ("#00AEF3", "#DE0100", "#FED105")

# %%
# creating powerpoint sides 
data = {'Democratic': 48, 'Republican': 46, 'Libertarian': 3}
fig = plt.figure(
    FigureClass=Waffle, 
    rows=5, 
    values=data, 
    # colors = ("#00AEF3", "#DE0100", "#FED105"),
    colors = ("#00AEF3", "#FFFFFF", "#FFFFFF"),
    # colors = ("#FFFFFF", "#DE0100", "#FFFFFF"),
    # colors = ("#00AEF3", "#DE0100", "#FED105"),
    # title={'label': 'Vote Percentage in 2016 US Presidential Election', 'loc': 'left'},
    labels=["{0} ({1}%)".format(k, v) for k, v in data.items()],
    legend={'loc': 'lower left', 'bbox_to_anchor': (0, -0.4), 'ncol': len(data), 'framealpha': 0}
)
plt.tight_layout()
fig.savefig('waffle_pow1.png')
# Out:
# <Waffle size 432x288 with 1 Axes>

# %%
# creating powerpoint sides 
data = {'Democratic': 48, 'Republican': 46, 'Libertarian': 3}
fig = plt.figure(
    FigureClass=Waffle, 
    rows=5, 
    values=data, 
    # colors = ("#00AEF3", "#DE0100", "#FED105"),
    # colors = ("#00AEF3", "#FFFFFF", "#FFFFFF"),
    colors = ("#FFFFFF", "#DE0100", "#FFFFFF"),
    # colors = ("#00AEF3", "#DE0100", "#FED105"),
    # title={'label': 'Vote Percentage in 2016 US Presidential Election', 'loc': 'left'},
    labels=["{0} ({1}%)".format(k, v) for k, v in data.items()],
    legend={'loc': 'lower left', 'bbox_to_anchor': (0, -0.4), 'ncol': len(data), 'framealpha': 0}
)
fig.savefig('waffle_pow2.png')
# Out:
# <Waffle size 432x288 with 1 Axes>

# %%
# creating powerpoint sides 
data = {'Democratic': 48, 'Republican': 46, 'Libertarian': 3}
fig = plt.figure(
    FigureClass=Waffle, 
    rows=5, 
    values=data, 
    # colors = ("#00AEF3", "#DE0100", "#FED105"),
    # colors = ("#00AEF3", "#FFFFFF", "#FFFFFF"),
    # colors = ("#FFFFFF", "#DE0100", "#FFFFFF"),
    colors = ("#FFFFFF", "#FFFFFF", "#FED105"),
    # title={'label': 'Vote Percentage in 2016 US Presidential Election', 'loc': 'left'},
    labels=["{0} ({1}%)".format(k, v) for k, v in data.items()],
    legend={'loc': 'lower left', 'bbox_to_anchor': (0, -0.4), 'ncol': len(data), 'framealpha': 0}
)
fig.savefig('waffle_pow3.png')
# Out:
# <Waffle size 432x288 with 1 Axes>

# %%
data = {'Democratic': 48, 'Republican': 46, 'Libertarian': 3}
fig = plt.figure(
    FigureClass=Waffle, 
    rows=5, 
    values=data, 
    colors = ("#00AEF3", "#DE0100", "#FED105"),
    title={'label': 'Vote Percentage in 2016 US Presidential Election', 'loc': 'left'},
    labels=["{0} ({1}%)".format(k, v) for k, v in data.items()],
    legend={'loc': 'lower left', 'bbox_to_anchor': (0, -0.4), 'ncol': len(data)}
)
# Out:
# <Waffle size 432x288 with 1 Axes>

# %%
fig = plt.figure(
    FigureClass=Waffle, 
    rows=5, 
    values=data, 
    colors = ("#00AEF3", "#DE0100", "#FED105"),
    title={'label': 'Vote Percentage in 2016 US Presidential Election', 'loc': 'left'},
    labels=["{0} ({1}%)".format(k, v) for k, v in data.items()],
    legend={'loc': 'lower left', 'bbox_to_anchor': (0, -0.4), 'ncol': len(data)},
    icons='child', icon_size=18, 
    icon_legend=True
    
)
# Out:
# <Waffle size 432x288 with 1 Axes>

# %% [markdown]
# ## Exercise 1: Waffle Chart

# %% [markdown]
# Say immigration from Scandinavia to Canada is comprised only of immigration from Sweden (49%), Norway (19%), and Denmark (32%) and we're interested in visualizing the contribution of each of these countries to the Scandinavian immigration to Canada.

# %% [markdown]
# Please write the code to create the following waffle chart.

# %%
# Your code here 
# Use the default colors

# %%
# Please don't run this cell, otherwise, it will remove the exercise plot image below. 
data = {'Sweden': 49, 'Norway': 19, 'Denmark': 32}
fig = plt.figure(
    FigureClass=Waffle, 
    rows=5, 
    values=data, 
    title={'label': 'Scandinavian immigration to Canada', 'loc': 'center'},
    labels=["{0} ({1}%)".format(k, v) for k, v in data.items()],
    legend={'loc': 'lower left', 'bbox_to_anchor': (0, -0.4), 'ncol': len(data)}
)
# Out:
# <Waffle size 432x288 with 1 Axes>

# %% [markdown]
# # Word Clouds

# %%
ls
# Out:
# DV0101EN-Exercise-Generating-Maps-in-Python.ipynb
# DV0101EN-Exercise-Waffle-Charts-Word-Clouds-and-Regression-Plots.ipynb
# android-games.csv
# april25_waffle_word_sea.ipynb

# %%
pip install pandas
# Out:
# ...
#   Using cached pandas-1.4.2-cp38-cp38-macosx_10_9_x86_64.whl (11.0 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
# pip install worldcloud
# Out:
# ERROR: Could not find a version that satisfies the requirement worldcloud (from versions: none)
# ERROR: No matching distribution found for worldcloud
# Note: you may need to restart the kernel to use updated packages.

# %%
# conda install -c conda-forge wordcloud

# %% [markdown]
# https://www.mentimeter.com/blog/awesome-presentations/85-poll-questions-for-every-occasion

# %% [markdown]
# When can we use word clouds?

# %%
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
df = pd.read_csv("android-games.csv")

# %%
df.head()
# Out:
#    rank                                         title  total ratings installs  \
# 0     1                Garena Free Fire- World Series       86273129  500.0 M
# 1     2                        PUBG MOBILE - Traverse       37276732  500.0 M
# 2     3                     Mobile Legends: Bang Bang       26663595  100.0 M
# 3     4                                   Brawl Stars       17971552  100.0 M
# 4     5  Sniper 3D: Fun Free Online FPS Shooting Game       14464235  500.0 M
#
#    average rating  growth (30 days)  growth (60 days)  price     category  \
# 0               4               2.1               6.9    0.0  GAME ACTION
# 1               4               1.8               3.6    0.0  GAME ACTION
# 2               4               1.5               3.2    0.0  GAME ACTION
# 3               4               1.4               4.4    0.0  GAME ACTION
# 4               4               0.8               1.5    0.0  GAME ACTION
#
# ...

# %%
df.isna().sum()
# Out:
# rank                0
# title               0
# total ratings       0
# installs            0
# average rating      0
# growth (30 days)    0
# growth (60 days)    0
# price               0
# category            0
# 5 star ratings      0
# 4 star ratings      0
# 3 star ratings      0
# 2 star ratings      0
# 1 star ratings      0
# paid                0
# dtype: int64

# %%
df.columns
# Out:
# Index(['rank', 'title', 'total ratings', 'installs', 'average rating',
#        'growth (30 days)', 'growth (60 days)', 'price', 'category',
#        '5 star ratings', '4 star ratings', '3 star ratings', '2 star ratings',
#        '1 star ratings', 'paid'],
#       dtype='object')

# %%
df['category'].unique()
# Out:
# array(['GAME ACTION', 'GAME ADVENTURE', 'GAME ARCADE', 'GAME BOARD',
#        'GAME CARD', 'GAME CASINO', 'GAME CASUAL', 'GAME EDUCATIONAL',
#        'GAME MUSIC', 'GAME PUZZLE', 'GAME RACING', 'GAME ROLE PLAYING',
#        'GAME SIMULATION', 'GAME SPORTS', 'GAME STRATEGY', 'GAME TRIVIA',
#        'GAME WORD'], dtype=object)

# %%
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# '/Users/rafiul/Dropbox (Personal)/UIW/data_viz'

# %%
with open('alice.txt','r') as f:
    text = f.read()
    words = text.split()

# %% [markdown]
# ## What is a Word Cloud?
# A word cloud (also known as a tag cloud) is a visual representation of words.
#
# A word cloud is simply a depiction of the importance of different words in the body of text. A word cloud works in a simple way; the more a specific word appears in a source of textual data the bigger and bolder it appears in the world cloud.

# %%
# words

# %%
# pip install wikipedia

# %%
import sys
# from os import path
# import numpy as np
# from PIL import Image
import wikipedia
from wordcloud import WordCloud, STOPWORDS

# %%
def get_wiki(query):
	# get best matching title for given query
	title = wikipedia.search(query)[0]
	# get wikipedia page for selected title
	page = wikipedia.page(title)
	return page.content

# %%
#get the text from wikipedia 
text = get_wiki('data science') 

# stopwords
stopwords = set(STOPWORDS)

# instantiate a word cloud object
wc = WordCloud()

# generate the word cloud
wc.generate(text)

# save the word cloud into a file 
wc.to_file('python_wc.png')
# display the word cloud
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
# print(get_wiki('python programming language'))

# %%
stopwords = set(STOPWORDS)
# stopwords
wc = WordCloud(background_color='white',max_words = 20, stopwords = stopwords)
wc.generate(text)
wc.to_file('python_wc_2.png')
# display the word cloud
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %%
import numpy as np

# %%
np.random.randint(0, 10, size=100, dtype=int)
# Out:
# array([6, 2, 5, 4, 4, 5, 5, 5, 2, 4, 9, 4, 6, 0, 3, 2, 3, 6, 3, 8, 5, 0,
#        2, 7, 8, 4, 5, 7, 6, 3, 0, 3, 3, 1, 3, 2, 6, 9, 6, 0, 2, 6, 9, 7,
#        9, 7, 7, 1, 5, 0, 8, 2, 6, 6, 9, 9, 7, 2, 8, 8, 3, 0, 7, 4, 3, 1,
#        2, 1, 7, 6, 2, 2, 5, 1, 0, 6, 5, 0, 5, 5, 1, 4, 0, 8, 4, 2, 4, 5,
#        8, 8, 8, 4, 2, 7, 6, 2, 1, 6, 4, 3])

# %%
subject_list = ['mathematics','physics','chemistry', 'biology','history','sociology','data science','subject X','subject Y','subject Y'] 
n_students = 5081
index = np.random.randint(0, len(subject_list), n_students)

# %%
# creating fake data
text_survey = ''
for i in index:
    text_survey+=subject_list[i]+' '
text_survey
# Out:
# 'subject Y subject Y data science chemistry history history data science sociology sociology sociology chemistry physics sociology subject Y subject X history subject Y history subject Y physics history subject Y biology history biology chemistry chemistry history physics chemistry subject Y data science chemistry subject X data science mathematics subject X data science data science data science biology subject X mathematics sociology subject X physics subject Y data science subject X subject Y subject X history mathematics data science history mathematics subject Y history chemistry data science history chemistry data science data science subject Y data science physics physics subject Y chemistry physics subject X chemistry subject X physics history chemistry sociology data science data science biology history mathematics sociology mathematics subject Y sociology biology sociology chemistry subject Y data science subject Y history data science biology data science physics history d
# ...

# %%
stopwords = set(STOPWORDS)
# stopwords
wc = WordCloud(background_color='white',max_words = 6, stopwords = stopwords)
wc.generate(text_survey)
fig = plt.figure(figsize=(10,8))
# display the word cloud
plt.imshow(wc)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# ## Exercise 2: Word Clouds

# %% [markdown]
# I created a text file (wordclouds.txt) by collecting the text from the following three webpages.
#
# Six effective ways to use word clouds to increase audience engagement
# https://www.vevox.com/blog/6-effective-ways-to-use-word-clouds-to-increase-audience-engagement#:~:text=A%20very%20popular%20way%20of,great%20starting%20point%20for%20discussions.
#
# The Pros and Cons of Word Clouds as Visualizations
# https://www.participoll.com/what-is-a-word-cloud-and-why-should-i-use-one/#:~:text=A%20Word%20Cloud%20is%20a,really%20thinks%20about%20a%20topic.
#
# What is a Word Cloud and Why Should I Use One?
# https://www.participoll.com/what-is-a-word-cloud-and-why-should-i-use-one/#:~:text=A%20Word%20Cloud%20is%20a,really%20thinks%20about%20a%20topic.

# %% [markdown]
# Please write code to create the following word cloud.

# %%
# Code here
# show maximum 15 words 

# reading the text file 
with open('wordclouds.txt','r') as f:
    text = f.read()
stopwords = set(STOPWORDS) 
# stopwords
wc = WordCloud(background_color='white',max_words = 15, stopwords = stopwords)
wc.generate(text)
fig = plt.figure(figsize=(10,8))
# display the word cloud
plt.imshow(wc)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
# don't run this cell
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %% [markdown]
# What insight you can get from the avobe word cloud?

# %%
# insight here

# %% [markdown]
# # Seaborn

# %%
# pip install seaborn

# %%
import seaborn as sns
# %matplotlib inline

# %%
df = sns.load_dataset('tips')

# %%
df.to_csv('tips.csv')

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
sns.lmplot(x='total_bill',y='tip',data=df)

# %%
sns.lmplot(x='total_bill',y='tip',hue='sex',data=df)

# %%
#markers
sns.lmplot(x='total_bill',y='tip',hue='sex',markers=['o','*'],data=df)

# %%
# grid 
sns.lmplot(x='total_bill',y='tip',col='sex',data=df)

# %%
# grid 
sns.lmplot(x='total_bill',y='tip',col='sex',row='time',data=df)

# %%
# grid 
sns.lmplot(x='total_bill',y='tip',col='day',row='time',hue='sex',data=df)

# %%
import seaborn as sns

# %%
taxis = sns.load_dataset("taxis")

# %% [markdown]
# **Documentation: https://seaborn.pydata.org/tutorial/regression.html **
# DataSets: https://github.com/mwaskom/seaborn-data

# %% [markdown]
# Teach: https://www.youtube.com/watch?v=9KUyWYpgJsE
# In this video, you’ll learn about creating regression plots using Seaborn. Seaborn is essential to Machine Learning! It allows you to create advanced plots to visualize your data. In this video, you’ll learn to explore in-built datasets in Seaborn, you’ll work with one dataset to create a regression plot using lmplot(), utilize hue() for specificity, and use markers() for customization. After watching this video and learning several Seaborn commands/plots, there’s an activity right below this description for you to try out on your own using the skills you learned here. Enjoy!
#
# SEABORN REGRESSION PLOTS ACTIVITY:
#
# Import libraries and load one Seaborn in-built dataset of your choice. Create linear regression plots and utilize hue, markers, and size to make the plots even more specific and effective for analysis.
#
# https://www.youtube.com/watch?v=-7RdAq1GOWs

# %% [markdown]
# ## Exercise 3: Seaborn lmplot
# Time to practice your new seaborn skills! Try to recreate the plots below.

# %% [markdown]
# ### The Data
# We will be working with a seaborn penguins data set for these exercises.
#
# Later on in the Machine Learning section of the course, we will revisit this data, and use it to predict survival rates of passengers. For now, we'll just focus on the visualization of the data with seaborn:

# %%
#loading packages 
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = sns.load_dataset('penguins').dropna()

# %%
# check the first 3 rows of the dataset 
# df.head(3)

# %% [markdown]
# **Penguins Data Column Definition:**
# - species a factor denoting penguin species (Adélie, Chinstrap and Gentoo)
# - island a factor denoting island in Palmer Archipelago, Antarctica (Biscoe, Dream or Torgersen)
# - bill_length_mm a number denoting bill length (millimeters)
# - bill_depth_mm a number denoting bill depth (millimeters)
# - flipper_length_mm an integer denoting flipper length (millimeters)
# - body_mass_g an integer denoting body mass (grams)
# - sex a factor denoting penguin sex (female, male)

# %% [markdown]
# ![image.png](attachment:da290108-a728-437e-982c-e688eb560941.png)
#
# Source: https://www.galapagos.org/blog/the-measure-of-a-penguin/

# %% [markdown]
# ### lm plots

# %%
sns.set_style('white')

# %%
# CODE HERE
# REPLICATE EXERCISE PLOT IMAGE BELOW
# BE CAREFUL NOT TO OVERWRITE CELL BELOW
# THAT WOULD REMOVE THE EXERCISE PLOT IMAGE!

# %%
# get the column names
df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='object')

# %% [markdown]
# Make a lm plot of bill length vs. flipper_length_mm

# %%
sns.lmplot(x='bill_length_mm', y= 'flipper_length_mm', data = df )

# %% [markdown]
# Please write short interpretation of the above figure.

# %% [markdown]
# Interpretation:

# %%
# please add option with the previos lmplot to create the following figure

# %%
# please don't write in this cell 
sns.lmplot(x='bill_length_mm', y= 'flipper_length_mm', hue='sex', data = df )

# %%
# please add markers to separate the categories

# %%
# please don't write in this cell 
sns.lmplot(x='bill_length_mm', y= 'flipper_length_mm', hue='sex', markers = ['o','*'] ,data = df )

# %%
# please add option with the previos lmplot to create the following figure

# %%
# please don't write in this cell 
sns.lmplot(x='bill_length_mm', y= 'flipper_length_mm', hue='sex', markers = ['o','*'],col='species', data = df)

# %% [markdown]
# https://www.youtube.com/watch?v=-_g_z-L-6tc

# %% [markdown]
# **Good job! Thank you for completing the exercises.**
